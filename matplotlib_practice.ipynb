# %%
# %matplotlib inline

# %%
# Import dependencies.
import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]


# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot
plt.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
ax = plt.axes()
ax.plot(x_axis, y_axis)

# %%
# Create the plot.
plt.plot(x_axis, y_axis)
plt.show()

# %%
# Create the plot and add a label for the legend.
plt.plot(x_axis, y_axis, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
# %matplotlib inline

# %%
# Import dependencies.
import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "OCT", "Nov", "Dec"]
# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot
plt.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot.
plt.bar(x_axis, y_axis, color="green", label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
# Create the plot
plt.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# to put the data on opposite axes, switch the arguments in the barnh() function.
# Create the plot
plt.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot.
plt.barh(x_axis, y_axis)
plt.gca().invert_yaxis()

# %%
# Create the plot.
plt.bar(x_axis, y_axis, color="green", label='Boston')
# Create labels for the x and y axes.
plt.xlabel(plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()
# Out:
#   File "<ipython-input-18-27eaed86f8bb>", line 5
#     plt.ylabel("Fare($)")
#       ^
# SyntaxError: invalid syntax

# %%
# Create the plot
plt.barh(x_axis, y_axis)

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "OCT", "Nov", "Dec"]
# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
plt.bar(x_axis,y_axis,color="m", label='Boston')

# %%
plt.barh(x_axis, y_axis)
plt.gca().invert_yaxis()

# %%
plt.bar(x_axis,y_axis,color="m", label='Boston')

# %%
plt.barh(x_axis, y_axis)
plt.gca().invert_yaxis()

# %%
plt.bar(x_axis,y_axis,color="m", label='Boston')

# %%
plt.barh(x_axis, y_axis)
plt.gca().invert_yaxis()

# %%
plt.bar(x_axis,y_axis,color="m", label='Boston')

# %%
# %matplotlib inline

# %%
# Import dependencies.
import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(y_axis, x_axis)

# %%
ax.bar(x_axis, y_axis, color="k", label='Chicago')

# %%
# %matplotlib inline

# %%
# Import dependencies.
import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(y_axis, x_axis)

# %%
fig, ax = plt.subplots()
ax.barh(y_axis, x_axis, color="c")

# %%
fig, ax =plt.subplots()
line, = ax.plot(x,y)
ax.set_xlabel('Date')
ax.set_ylabel('Fare($)')

# %%
plt.barh(x_axis, y_axis)
plt.gca().invert_yaxis()

# %%
plt.barh(x_axis, y_axis)
plt.gca().invert_yaxis()

# %%
# %matplotlib inline

# %%
# Import dependencies.
import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(y_axis, x_axis)

# %%
plt.barh(x_axis, y_axis)
plt.gca().invert_yaxis()

# %%
# Create a title.
plt.title("PyBer Fare by Month")

# %%
plt.barh(x_axis, y_axis)
plt.gca().invert_yaxis()

# %%
fig, ax = plt.subplots()
ax.barh(y_axis, x_axis, color="c")

# %%
plt.barh(x_axis, y_axis)
plt.gca().invert_yaxis()

# %%
plt.bar(x_axis, y_axis, color="cyan", label='chicago')

# %%
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis, color="cyan")
ax.invert_yaxis()
ax.set_xlabel('FARE($)')
ax.set_ylabel('Date')

# Create a title.
plt.title("PyBer  Fare by Month")
plt.legend(['Chicago'])

# %%
# %matplotlib inline

# %%
# Import dependencies.
import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]


# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

plt.scatter(x_axis, y_axis, c='r')
plt.xlim(0, 50)
ax.set_xlabel('FARE($)')
ax.set_ylabel('Date')
# Create a title.
plt.title("PyBer  Fare by Month")
plt.legend(['Chicago'])

# %%
# When we execute the code, the result should be identical to the graph when we used  plt.plot(x_axis, y_axis, 'o').
plt.scatter(x_axis, y_axis)

# %%
# %matplotlib inline

# %%
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis, color="cyan")
ax.invert_yaxis()
ax.set_xlabel('FARE($)')
ax.set_ylabel('Date')

# Create a title.
plt.title("PyBer  Fare by Month")
plt.legend(['Chicago'])

# %%
ax.barh(x_axis, y_axis, color="red")
plot(ydata, xdata) %// 
ax.invert_yaxis()
ax.set_xlabel('FARE($)')
ax.set_ylabel('Date')
# Create a title.
plt.title("PyBer  Fare by Month")
plt.legend(['Chicago'])

# %%
# This switches the plot from a line chart to a scatter plot.
plt.plot(x_axis, y_axis, 'o')
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis, color="red")
ax.invert_yaxis()

# %%
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis, color="red")
ax.invert_yaxis()
# Set the y limit between 0 and 45.
ax.set_xlabel('FARE($)')
ax.set_ylabel('Date')
# Create a title.
plt.title("PyBer  Fare by Month")
plt.legend(['Chicago'])

# %%
# %matplotlib inline

# %%
# Import dependencies.
import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month.
y_axis = ["Dec", "Nov", "Oct", "Sept", "Aug", "July", "June", "May", "April", "Mar", "Feb", "Jan"]



# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
x_axis = [20.09, 20.71, 27.90, 11.85, 10.56, 43.82, 27.04, 32.34, 35.42, 39.20, 23.24, 10.02]


plt.scatter(x_axis, y_axis, c='r')

plt.title("PyBer Fare by Month")

plt.legend(['Chicago'])
plt.xlim(0, 50)
plt.xlabel("Fare($)")
plt.ylabel("Date")
# Out:
# Text(0, 0.5, 'Date')
